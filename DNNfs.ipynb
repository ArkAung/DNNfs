# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import math


def softmax(z):
    z -= np.max(z, axis=1, keepdims=True)
    ans = np.exp(z) / np.sum(np.exp(z), axis=1, keepdims=True)
    return ans


def relu(z):
    z[z < 0] = 0
    return z


def relu_prime(z):
    z[z <= 0] = 0
    z[z > 0] = 1
    return z


# Just for the sake of saving  computing time to recalculate y_hat in each mini_batch
def stochastic_J(w1, w2, y_hat, images, labels, alpha=0.):
    x = images
    y = labels
    m = x.shape[0]
    cost_mat = np.multiply(y, np.log(y_hat))
    cost = (-1. / m) * np.sum(np.sum(cost_mat, axis=1))
    # Regularize
    cost += (alpha/(2 * m)) * (np.linalg.norm(w1) + np.linalg.norm(w2))
    return cost


def J(w1, w2, b1, b2, images, labels, alpha=0.):
    x = images
    y = labels
    m = x.shape[0]
    h1, y_hat = feedforward(w1, w2, b1, b2, x, y)
    cost_mat = np.multiply(y, np.log(y_hat))
    cost = (-1. / m) * np.sum(np.sum(cost_mat, axis=1))
    # Regularize
    cost += (alpha/(2 * m)) * (np.linalg.norm(w1) + np.linalg.norm(w2))
    return cost


def feedforward(w1, w2, b1, b2, images, labels):
    x = images
    h1 = relu(x.dot(w1.T) + b1)
    y_hat = softmax(h1.dot(w2.T) + b2)
    return h1, y_hat


def grad_layer2(h1, y_hat, w1, w2, images, labels, alpha=0.):
    y = labels
    m = y.shape[0]
    dJ_dz2 = (y_hat - y)/m
    dJ_dw2 = dJ_dz2.T.dot(h1)
    #Regularize
    dJ_dw2 += (alpha/m) * w2
    dJ_b2 = np.sum(dJ_dz2, axis=0, keepdims=True)
    return dJ_dw2, dJ_b2


def grad_layer1(h1, y_hat, w1, w2, images, labels, alpha=0.):
    x = images
    y = labels
    m = y.shape[0]
    dJ_dz2 = (y_hat - y)/m
    dJ_dh1 = dJ_dz2.dot(w2)
    g = dJ_dh1 * relu_prime(x.dot(w1.T))  # dJ/dz1
    dJ_dw1 = g.T.dot(x)
    # Regularize
    dJ_dw1 += (alpha/m) * w1
    dJ_db1 = np.sum(g, axis=0, keepdims=True)
    return dJ_dw1, dJ_db1


def sgd(train_images, train_labels, val_images, val_labels, h_nodes, epsilon, batch_size, epochs, alpha=0., searching=False):
    x = train_images
    y = train_labels
    sample_size, dimensions = x.shape
    classes = y.shape[1]
    cost_history = np.array([])

    w1_range = math.sqrt(2./dimensions)
    w1 = np.random.uniform(-w1_range, w1_range, (h_nodes, dimensions))
    b1 = np.ones((1, h_nodes)) * 0.1
    w2_range = math.sqrt(2. / h_nodes)
    w2 = np.random.uniform(-w2_range, w2_range, (classes, h_nodes))
    b2 = np.ones((1, classes)) * 0.1

    num_batches = sample_size / batch_size
    for e in xrange(epochs):
        batch_history = np.array([])

        x_y = np.append(x, y, axis=1)
        np.random.shuffle(x_y)
        x_s = x_y[:, :dimensions]
        y_s = x_y[:, dimensions:]
        for i in xrange(num_batches):
            start = i * batch_size
            end = start + batch_size
            x_batch = x_s[start:end]
            y_batch = y_s[start:end]
            # Do feedforward pass
            h1, y_hat = feedforward(w1, w2, b1, b2, x_batch, y_batch)
            # Find dJ/dw1 and dJ/d1
            gradw1, gradb1 = grad_layer1(h1, y_hat, w1, w2, x_batch, y_batch, alpha)
            # Find dJ/dw2 and dJ/dwb2
            gradw2, gradb2 = grad_layer2(h1, y_hat, w1, w2, x_batch, y_batch, alpha)
            w1 -= (epsilon * gradw1)
            b1 -= (epsilon * gradb1)
            w2 -= (epsilon * gradw2)
            b2 -= (epsilon * gradb2)
            # Cost of current mini-batch
            cost = stochastic_J(w1, w2, y_hat, x_batch, y_batch, alpha)
            # List of costs for all the mini-batches in current epoch
            batch_history = np.append(batch_history, cost)

        epoch_cost = np.mean(batch_history)
        # List of costs for epochs
        cost_history = np.append(cost_history, epoch_cost)
        # Accuracy of on validation data set after each epoch
        validation_acc = report_accuracy(w1, w2, b1, b2, val_images, val_labels)
        if e % 2 == 0:
            print("Epochs: %d Cost: %.5f Validation Acc: %.2f ||w1||: %.5f ||w2||: %.5f" % (
                e, epoch_cost, validation_acc, np.linalg.norm(w1), np.linalg.norm(w2)))

    if searching:
        # When searching best hyperparameters, return final cost (last element in cost_history) and
        # final validation accuracy. These will be heuristics when choosing the best hyperparameters
        return cost_history[-1], validation_acc

    plt.plot(np.linspace(epochs-20, epochs, 20), cost_history[-20:], label="Training Cost")
    plt.legend('Cost')
    plt.ylabel('Training Cost')
    plt.xlabel('Epochs')
    plt.title("Cross-entropy cost values")
    plt.show()
    return w1, w2, b1, b2


def reportCosts(w1, w2, b1, b2, trainImg , trainLbl, valiImg, valiLbl, testImg, testLbl, alpha=0.):
    print "Training cost: {}".format(J(w1, w2, b1, b2, trainImg, trainLbl, alpha))
    print "Validation cost:  {}".format(J(w1, w2, b1, b2, valiImg, valiLbl, alpha))
    print "Testing cost:  {}".format(J(w1, w2, b1, b2, testImg, testLbl, alpha))


def report_accuracy(w1, w2, b1, b2, images, labels):
    h1, y_hat = feedforward(w1, w2, b1, b2, images, labels)
    acc = np.mean(np.argmax(y_hat, axis=1) == np.argmax(labels, axis=1))
    return acc * 100


def predict(images, labels, w1, w2, b1, b2):
    h1, y_hat = feedforward(w1, w2, b1, b2, images, labels)
    predicted = np.argmax(y_hat)
    real = np.argmax(labels)
    return predicted, real


def findBestHyperparameters(train_images, train_labels, val_images, val_labels):
    h_nodes = [20, 20, 60, 50, 80, 30, 60, 40, 60, 20, 80]
    l_rate = [0.33, 1e-2, 0.4, 0.15, 0.001, 0.01, 0.006, 0.06, 0.2, 0.007, 0.1]
    b_size = [100, 250, 50, 125, 500, 275, 88, 40, 100, 625, 25]
    alpha = [0, 0.8, 0.02, 1e2, 5.0, 0.2, 0.3, 0.7, 0.05, 0.1, 0.9]
    epochs = [10, 20, 50, 10, 30, 40, 30, 20, 50, 10, 40]
    min_cost = 100
    max_acc = 0
    best = 0
    for i in range(11):
        print ("[%d] Trying parameters - Hidden Nodes: %d Learning Rate: %.6f Batch Size: %d Alpha: %.3f Epochs: %d" % (
            i, h_nodes[i], l_rate[i], b_size[i], alpha[i], epochs[i]))
        cost, acc = sgd(train_images, train_labels, val_images, val_labels,
                        h_nodes[i], l_rate[i], b_size[i], epochs[i], alpha[i], searching=True)
        if cost < min_cost:
            min_cost = cost
            best = i
        if acc > max_acc:
            max_acc = acc
            best = i
        print ("Current best parameters - Hidden Nodes: %d Learning Rate: %.6f Batch Size: %d Alpha: %.3f Epochs: %d" %
               (h_nodes[best], l_rate[best], b_size[best], alpha[best], epochs[best]))

    return h_nodes[best], l_rate[best], b_size[best], alpha[best], epochs[best]

#####CHECK GRAD######
def checkgrad_unpack(w, images, labels):
    w1_idx = images.shape[1] * hidden_nodes
    b1_idx = hidden_nodes
    w2_idx = labels.shape[1] * hidden_nodes
    b2_idx = 10
    w1 = np.reshape(w[:w1_idx], (hidden_nodes, images.shape[1]))
    b1 = np.reshape(w[w1_idx:w1_idx + b1_idx], (1, hidden_nodes))
    w2 = np.reshape(w[w1_idx + b1_idx:w1_idx + b1_idx + w2_idx], (labels.shape[1], hidden_nodes))
    b2 = np.reshape(w[w1_idx + b1_idx + w2_idx:], (1, 10))
    return w1, b1, w2, b2


def checkgrad_cost(w, images, labels, alpha=.0):
    w1, b1, w2, b2 = checkgrad_unpack(w, images, labels)
    cost = J(w1, w2, b1, b2, images, labels, alpha)
    return cost


def checkgrad_grad(w, images, labels, alpha=.0):
    w1, b1, w2, b2 = checkgrad_unpack(w, images, labels)
    h1, y_hat = feedforward(w1, w2, b1, b2, images, labels)
    gw2, gb2 = grad_layer2(h1, y_hat, w1, w2, images, labels, alpha)
    gw1, gb1 = grad_layer1(h1, y_hat, w1, w2, images, labels, alpha)
    final_w = np.concatenate((gw1.flatten(), gb1.flatten(), gw2.flatten(), gb2.flatten()))
    return final_w
#####END OF CHECK GRAD######

if __name__ == "__main__":
    # Load data
    if 'trainingImages' not in globals():
        trainingImages = np.load("datasets/mnist_train_images.npy")
        trainingLabels = np.load("datasets/mnist_train_labels.npy")
        validationImages = np.load("datasets/mnist_validation_images.npy")
        validationLabels = np.load("datasets/mnist_validation_labels.npy")
        testingImages = np.load("datasets/mnist_test_images.npy")
        testingLabels = np.load("datasets/mnist_test_labels.npy")

    import time

    start = time.time()
    hidden_nodes, learning_rate, batch_size, ridge_term, epochs = findBestHyperparameters(trainingImages, trainingLabels,
                                                                                          validationImages, validationLabels)
    # hidden_nodes, learning_rate, batch_size, ridge_term, epochs = 60, 0.20, 100, 0.05, 50
    print ("Best parameters - Hidden Nodes: %d Learning Rate: %.6f Batch Size: %d Alpha: %.3f Epochs: %d" %
           (hidden_nodes, learning_rate, batch_size, ridge_term, epochs))
    w_1, w_2, b_1, b_2 = sgd(trainingImages, trainingLabels, validationImages, validationLabels,
                             hidden_nodes, learning_rate, batch_size, epochs, ridge_term)

    from scipy.optimize import check_grad
    checkgrad_w = np.concatenate((w_1.flatten(), b_1.flatten(), w_2.flatten(), b_2.flatten()))
    print ("Check grad value is ", check_grad(checkgrad_cost, checkgrad_grad, checkgrad_w,
                                              trainingImages[1:100], trainingLabels[1:100],ridge_term))

    dt = int(time.time() - start)
    print("Execution time %d sec" % dt)

    reportCosts(w_1, w_2, b_1, b_2, trainingImages, trainingLabels, validationImages, validationLabels, testingImages, testingLabels)
    print "Accuracy on Validation set: ", report_accuracy(w_1, w_2, b_1, b_2, validationImages, validationLabels), "%"
    print "Accuracy on Testing set: ", report_accuracy(w_1, w_2, b_1, b_2, testingImages, testingLabels), "%"
# Out:
# [0] Trying parameters - Hidden Nodes: 20 Learning Rate: 0.330000 Batch Size: 100 Alpha: 0.000 Epochs: 10
# Epochs: 0 Cost: 0.40133 Validation Acc: 92.24 ||w1||: 7.82725 ||w2||: 6.31107
# Epochs: 2 Cost: 0.19128 Validation Acc: 95.32 ||w1||: 10.43702 ||w2||: 7.94636
# Epochs: 4 Cost: 0.15294 Validation Acc: 95.60 ||w1||: 12.06228 ||w2||: 8.89890
# Epochs: 6 Cost: 0.13608 Validation Acc: 95.36 ||w1||: 13.31749 ||w2||: 9.54789
# Epochs: 8 Cost: 0.12297 Validation Acc: 95.32 ||w1||: 14.34750 ||w2||: 10.05230
# Current best parameters - Hidden Nodes: 20 Learning Rate: 0.330000 Batch Size: 100 Alpha: 0.000 Epochs: 10
# [1] Trying parameters - Hidden Nodes: 20 Learning Rate: 0.010000 Batch Size: 250 Alpha: 0.800 Epochs: 20
# Epochs: 0 Cost: 1.94180 Validation Acc: 64.70 ||w1||: 3.77240 ||w2||: 2.73370
# Epochs: 2 Cost: 0.92376 Validation Acc: 82.46 ||w1||: 4.32525 ||w2||: 3.49759
# Epochs: 4 Cost: 0.62517 Validation Acc: 86.32 ||w1||: 4.68361 ||w2||: 3.96167
# Epochs: 6 Cost: 0.51560 Validation Acc: 88.18 ||w1||: 4.90657 ||w2||: 4.24739
# Epochs: 8 Cost: 0.46093 Validation Acc: 88.94 ||w1||: 5.05730 ||w2||: 4.44240
# Epochs: 10 Cost: 0.42847 Validation Acc: 89.40 ||w1||: 5.16543 ||w2||: 4.58506
# Epochs: 12 Cost: 0.40661 Validation Acc: 89.86 ||w1||: 5.24690 ||w2||: 4.69536
# Epochs: 14 Cost: 0.39044 Validation Acc: 90.26 ||w1||: 5.31013 ||w2||: 4.78355
# Epochs: 16 Cost: 0.37775 Validation Acc: 90.54 ||w1||: 5.36087 ||w2||: 4.85654
# Epochs: 18 Cost: 0.36760 Validation Acc: 90.78 ||w1||: 5.40271 ||w2||: 4.91877
# Current best parameters - Hidden Nodes: 20 Learning Rate: 0.330000 Batch Size: 100 Alpha: 0.000 Epochs: 10
# [2] Trying parameters - Hidden Nodes: 60 Learning Rate: 0.400000 Batch Size: 50 Alpha: 0.020 Epochs: 50
# Epochs: 0 Cost: 0.28132 Validation Acc: 96.00 ||w1||: 11.63040 ||w2||: 7.85976
# Epochs: 2 Cost: 0.10819 Validation Acc: 96.96 ||w1||: 13.43387 ||w2||: 9.17174
# Epochs: 4 Cost: 0.08632 Validation Acc: 97.24 ||w1||: 13.96770 ||w2||: 9.70738
# Epochs: 6 Cost: 0.07592 Validation Acc: 97.36 ||w1||: 14.12740 ||w2||: 10.00447
# Epochs: 8 Cost: 0.07067 Validation Acc: 97.38 ||w1||: 14.21615 ||w2||: 10.16348
# Epochs: 10 Cost: 0.06634 Validation Acc: 97.38 ||w1||: 14.30570 ||w2||: 10.32395
# Epochs: 12 Cost: 0.06482 Validation Acc: 97.30 ||w1||: 14.35426 ||w2||: 10.43493
# Epochs: 14 Cost: 0.06403 Validation Acc: 97.66 ||w1||: 14.38017 ||w2||: 10.46037
# Epochs: 16 Cost: 0.06288 Validation Acc: 97.64 ||w1||: 14.48268 ||w2||: 10.55348
# Epochs: 18 Cost: 0.06146 Validation Acc: 97.52 ||w1||: 14.47966 ||w2||: 10.53659
# Epochs: 20 Cost: 0.06177 Validation Acc: 97.76 ||w1||: 14.53422 ||w2||: 10.54454
# Epochs: 22 Cost: 0.06193 Validation Acc: 97.28 ||w1||: 14.57069 ||w2||: 10.55142
# Epochs: 24 Cost: 0.06009 Validation Acc: 97.48 ||w1||: 14.60914 ||w2||: 10.58029
# Epochs: 26 Cost: 0.06145 Validation Acc: 97.46 ||w1||: 14.67293 ||w2||: 10.56089
# Epochs: 28 Cost: 0.05941 Validation Acc: 97.78 ||w1||: 14.66601 ||w2||: 10.57708
# Epochs: 30 Cost: 0.06197 Validation Acc: 97.62 ||w1||: 14.78544 ||w2||: 10.56893
# Epochs: 32 Cost: 0.06237 Validation Acc: 97.60 ||w1||: 14.87735 ||w2||: 10.55905
# Epochs: 34 Cost: 0.06178 Validation Acc: 96.58 ||w1||: 14.88637 ||w2||: 10.56129
# Epochs: 36 Cost: 0.06210 Validation Acc: 97.80 ||w1||: 14.91233 ||w2||: 10.54369
# Epochs: 38 Cost: 0.06263 Validation Acc: 97.76 ||w1||: 14.95458 ||w2||: 10.54875
# Epochs: 40 Cost: 0.06188 Validation Acc: 97.30 ||w1||: 15.01761 ||w2||: 10.56282
# Epochs: 42 Cost: 0.06368 Validation Acc: 97.64 ||w1||: 15.07778 ||w2||: 10.51134
# Epochs: 44 Cost: 0.06327 Validation Acc: 97.20 ||w1||: 15.13597 ||w2||: 10.54705
# Epochs: 46 Cost: 0.06345 Validation Acc: 97.40 ||w1||: 15.18926 ||w2||: 10.54424
# Epochs: 48 Cost: 0.06382 Validation Acc: 97.50 ||w1||: 15.25512 ||w2||: 10.52979
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.400000 Batch Size: 50 Alpha: 0.020 Epochs: 50
# [3] Trying parameters - Hidden Nodes: 50 Learning Rate: 0.150000 Batch Size: 125 Alpha: 100.000 Epochs: 10
# Epochs: 0 Cost: 2.36732 Validation Acc: 11.00 ||w1||: 0.00000 ||w2||: 0.02263
# Epochs: 2 Cost: 2.30868 Validation Acc: 11.26 ||w1||: 0.00000 ||w2||: 0.01606
# Epochs: 4 Cost: 2.30880 Validation Acc: 11.26 ||w1||: 0.00000 ||w2||: 0.01996
# Epochs: 6 Cost: 2.30918 Validation Acc: 11.26 ||w1||: 0.00000 ||w2||: 0.02101
# Epochs: 8 Cost: 2.30932 Validation Acc: 11.26 ||w1||: 0.00000 ||w2||: 0.02063
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.400000 Batch Size: 50 Alpha: 0.020 Epochs: 50
# [4] Trying parameters - Hidden Nodes: 80 Learning Rate: 0.001000 Batch Size: 500 Alpha: 5.000 Epochs: 30
# Epochs: 0 Cost: 2.34843 Validation Acc: 17.04 ||w1||: 7.29173 ||w2||: 2.60375
# Epochs: 2 Cost: 2.27122 Validation Acc: 29.36 ||w1||: 7.27693 ||w2||: 2.60181
# Epochs: 4 Cost: 2.19727 Validation Acc: 39.10 ||w1||: 7.26408 ||w2||: 2.60600
# Epochs: 6 Cost: 2.12143 Validation Acc: 47.10 ||w1||: 7.25319 ||w2||: 2.61604
# Epochs: 8 Cost: 2.04238 Validation Acc: 54.68 ||w1||: 7.24434 ||w2||: 2.63181
# Epochs: 10 Cost: 1.96068 Validation Acc: 60.52 ||w1||: 7.23757 ||w2||: 2.65314
# Epochs: 12 Cost: 1.87734 Validation Acc: 64.64 ||w1||: 7.23283 ||w2||: 2.67967
# Epochs: 14 Cost: 1.79337 Validation Acc: 67.94 ||w1||: 7.23001 ||w2||: 2.71092
# Epochs: 16 Cost: 1.70966 Validation Acc: 70.50 ||w1||: 7.22895 ||w2||: 2.74630
# Epochs: 18 Cost: 1.62723 Validation Acc: 73.02 ||w1||: 7.22944 ||w2||: 2.78510
# Epochs: 20 Cost: 1.54711 Validation Acc: 74.86 ||w1||: 7.23126 ||w2||: 2.82655
# Epochs: 22 Cost: 1.47033 Validation Acc: 76.46 ||w1||: 7.23414 ||w2||: 2.86990
# Epochs: 24 Cost: 1.39782 Validation Acc: 77.70 ||w1||: 7.23782 ||w2||: 2.91438
# Epochs: 26 Cost: 1.33019 Validation Acc: 78.76 ||w1||: 7.24206 ||w2||: 2.95934
# Epochs: 28 Cost: 1.26770 Validation Acc: 79.50 ||w1||: 7.24662 ||w2||: 3.00419
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.400000 Batch Size: 50 Alpha: 0.020 Epochs: 50
# [5] Trying parameters - Hidden Nodes: 30 Learning Rate: 0.010000 Batch Size: 275 Alpha: 0.200 Epochs: 40
# Epochs: 0 Cost: 2.01281 Validation Acc: 68.76 ||w1||: 4.54874 ||w2||: 2.76379
# Epochs: 2 Cost: 0.90895 Validation Acc: 83.40 ||w1||: 5.03664 ||w2||: 3.53498
# Epochs: 4 Cost: 0.59963 Validation Acc: 87.16 ||w1||: 5.36928 ||w2||: 4.01088
# Epochs: 6 Cost: 0.49327 Validation Acc: 88.52 ||w1||: 5.58709 ||w2||: 4.31080
# Epochs: 8 Cost: 0.44107 Validation Acc: 89.38 ||w1||: 5.74376 ||w2||: 4.52307
# Epochs: 10 Cost: 0.40972 Validation Acc: 89.68 ||w1||: 5.86387 ||w2||: 4.68474
# Epochs: 12 Cost: 0.38851 Validation Acc: 90.20 ||w1||: 5.96029 ||w2||: 4.81433
# Epochs: 14 Cost: 0.37299 Validation Acc: 90.50 ||w1||: 6.04059 ||w2||: 4.92239
# Epochs: 16 Cost: 0.36079 Validation Acc: 90.82 ||w1||: 6.10909 ||w2||: 5.01480
# Epochs: 18 Cost: 0.35099 Validation Acc: 91.14 ||w1||: 6.16878 ||w2||: 5.09577
# Epochs: 20 Cost: 0.34282 Validation Acc: 91.40 ||w1||: 6.22187 ||w2||: 5.16809
# Epochs: 22 Cost: 0.33575 Validation Acc: 91.44 ||w1||: 6.26975 ||w2||: 5.23362
# Epochs: 24 Cost: 0.32959 Validation Acc: 91.64 ||w1||: 6.31316 ||w2||: 5.29341
# Epochs: 26 Cost: 0.32424 Validation Acc: 91.78 ||w1||: 6.35293 ||w2||: 5.34841
# Epochs: 28 Cost: 0.31940 Validation Acc: 91.98 ||w1||: 6.38982 ||w2||: 5.39968
# Epochs: 30 Cost: 0.31490 Validation Acc: 92.02 ||w1||: 6.42403 ||w2||: 5.44753
# Epochs: 32 Cost: 0.31080 Validation Acc: 92.18 ||w1||: 6.45628 ||w2||: 5.49272
# Epochs: 34 Cost: 0.30700 Validation Acc: 92.16 ||w1||: 6.48687 ||w2||: 5.53580
# Epochs: 36 Cost: 0.30337 Validation Acc: 92.36 ||w1||: 6.51593 ||w2||: 5.57688
# Epochs: 38 Cost: 0.30001 Validation Acc: 92.44 ||w1||: 6.54359 ||w2||: 5.61601
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.400000 Batch Size: 50 Alpha: 0.020 Epochs: 50
# [6] Trying parameters - Hidden Nodes: 60 Learning Rate: 0.006000 Batch Size: 88 Alpha: 0.300 Epochs: 30
# Epochs: 0 Cost: 1.64769 Validation Acc: 80.64 ||w1||: 6.50276 ||w2||: 3.14769
# Epochs: 2 Cost: 0.60302 Validation Acc: 87.54 ||w1||: 6.86566 ||w2||: 4.06144
# Epochs: 4 Cost: 0.46313 Validation Acc: 89.34 ||w1||: 6.98869 ||w2||: 4.44780
# Epochs: 6 Cost: 0.41208 Validation Acc: 90.34 ||w1||: 7.02590 ||w2||: 4.66797
# Epochs: 8 Cost: 0.38459 Validation Acc: 90.82 ||w1||: 7.02493 ||w2||: 4.81472
# Epochs: 10 Cost: 0.36630 Validation Acc: 91.24 ||w1||: 7.00521 ||w2||: 4.92294
# Epochs: 12 Cost: 0.35266 Validation Acc: 91.46 ||w1||: 6.97585 ||w2||: 5.00854
# Epochs: 14 Cost: 0.34156 Validation Acc: 91.76 ||w1||: 6.94221 ||w2||: 5.08042
# Epochs: 16 Cost: 0.33197 Validation Acc: 91.98 ||w1||: 6.90674 ||w2||: 5.14328
# Epochs: 18 Cost: 0.32371 Validation Acc: 92.08 ||w1||: 6.87102 ||w2||: 5.19944
# Epochs: 20 Cost: 0.31605 Validation Acc: 92.42 ||w1||: 6.83614 ||w2||: 5.25110
# Epochs: 22 Cost: 0.30927 Validation Acc: 92.70 ||w1||: 6.80223 ||w2||: 5.29856
# Epochs: 24 Cost: 0.30308 Validation Acc: 92.86 ||w1||: 6.76994 ||w2||: 5.34298
# Epochs: 26 Cost: 0.29727 Validation Acc: 93.16 ||w1||: 6.73871 ||w2||: 5.38413
# Epochs: 28 Cost: 0.29179 Validation Acc: 93.30 ||w1||: 6.70969 ||w2||: 5.42367
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.400000 Batch Size: 50 Alpha: 0.020 Epochs: 50
# [7] Trying parameters - Hidden Nodes: 40 Learning Rate: 0.060000 Batch Size: 40 Alpha: 0.700 Epochs: 20
# Epochs: 0 Cost: 0.60887 Validation Acc: 90.88 ||w1||: 4.22287 ||w2||: 4.08106
# Epochs: 2 Cost: 0.46196 Validation Acc: 91.50 ||w1||: 4.12520 ||w2||: 4.09217
# Epochs: 4 Cost: 0.45613 Validation Acc: 91.34 ||w1||: 4.13915 ||w2||: 4.09146
# Epochs: 6 Cost: 0.45347 Validation Acc: 90.20 ||w1||: 4.14604 ||w2||: 4.09026
# Epochs: 8 Cost: 0.45380 Validation Acc: 91.64 ||w1||: 4.14627 ||w2||: 4.08240
# Epochs: 10 Cost: 0.45387 Validation Acc: 90.36 ||w1||: 4.13849 ||w2||: 4.06728
# Epochs: 12 Cost: 0.45398 Validation Acc: 91.44 ||w1||: 4.15477 ||w2||: 4.07728
# Epochs: 14 Cost: 0.45571 Validation Acc: 91.40 ||w1||: 4.15941 ||w2||: 4.07927
# Epochs: 16 Cost: 0.45733 Validation Acc: 91.30 ||w1||: 4.13743 ||w2||: 4.05903
# Epochs: 18 Cost: 0.45767 Validation Acc: 91.26 ||w1||: 4.15898 ||w2||: 4.08439
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.400000 Batch Size: 50 Alpha: 0.020 Epochs: 50
# [8] Trying parameters - Hidden Nodes: 60 Learning Rate: 0.200000 Batch Size: 100 Alpha: 0.050 Epochs: 50
# Epochs: 0 Cost: 0.41399 Validation Acc: 93.84 ||w1||: 8.36564 ||w2||: 6.04284
# Epochs: 2 Cost: 0.16993 Validation Acc: 95.88 ||w1||: 9.53084 ||w2||: 7.55348
# Epochs: 4 Cost: 0.12468 Validation Acc: 96.76 ||w1||: 10.19840 ||w2||: 8.41621
# Epochs: 6 Cost: 0.10112 Validation Acc: 97.24 ||w1||: 10.62296 ||w2||: 8.98686
# Epochs: 8 Cost: 0.08767 Validation Acc: 97.42 ||w1||: 10.89156 ||w2||: 9.36884
# Epochs: 10 Cost: 0.07894 Validation Acc: 97.52 ||w1||: 11.07997 ||w2||: 9.65266
# Epochs: 12 Cost: 0.07305 Validation Acc: 97.56 ||w1||: 11.21141 ||w2||: 9.86123
# Epochs: 14 Cost: 0.06877 Validation Acc: 97.74 ||w1||: 11.31972 ||w2||: 10.03261
# Epochs: 16 Cost: 0.06554 Validation Acc: 97.92 ||w1||: 11.40066 ||w2||: 10.15889
# Epochs: 18 Cost: 0.06258 Validation Acc: 97.78 ||w1||: 11.46731 ||w2||: 10.26820
# Epochs: 20 Cost: 0.06064 Validation Acc: 97.84 ||w1||: 11.51614 ||w2||: 10.35116
# Epochs: 22 Cost: 0.05893 Validation Acc: 97.68 ||w1||: 11.55313 ||w2||: 10.41341
# Epochs: 24 Cost: 0.05747 Validation Acc: 97.84 ||w1||: 11.59493 ||w2||: 10.47292
# Epochs: 26 Cost: 0.05682 Validation Acc: 97.78 ||w1||: 11.62595 ||w2||: 10.51689
# Epochs: 28 Cost: 0.05551 Validation Acc: 97.74 ||w1||: 11.66468 ||w2||: 10.56769
# Epochs: 30 Cost: 0.05499 Validation Acc: 97.82 ||w1||: 11.68997 ||w2||: 10.59592
# Epochs: 32 Cost: 0.05433 Validation Acc: 97.72 ||w1||: 11.72210 ||w2||: 10.63252
# Epochs: 34 Cost: 0.05341 Validation Acc: 97.92 ||w1||: 11.74597 ||w2||: 10.65320
# Epochs: 36 Cost: 0.05348 Validation Acc: 98.02 ||w1||: 11.76308 ||w2||: 10.66351
# Epochs: 38 Cost: 0.05291 Validation Acc: 97.92 ||w1||: 11.78462 ||w2||: 10.68359
# Epochs: 40 Cost: 0.05225 Validation Acc: 97.84 ||w1||: 11.81158 ||w2||: 10.70774
# Epochs: 42 Cost: 0.05186 Validation Acc: 97.86 ||w1||: 11.82806 ||w2||: 10.72279
# Epochs: 44 Cost: 0.05160 Validation Acc: 97.78 ||w1||: 11.84420 ||w2||: 10.73073
# Epochs: 46 Cost: 0.05188 Validation Acc: 97.86 ||w1||: 11.86198 ||w2||: 10.73701
# Epochs: 48 Cost: 0.05136 Validation Acc: 98.00 ||w1||: 11.88270 ||w2||: 10.74671
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.200000 Batch Size: 100 Alpha: 0.050 Epochs: 50
# [9] Trying parameters - Hidden Nodes: 20 Learning Rate: 0.007000 Batch Size: 625 Alpha: 0.100 Epochs: 10
# Epochs: 0 Cost: 2.23741 Validation Acc: 36.20 ||w1||: 3.66001 ||w2||: 2.67139
# Epochs: 2 Cost: 1.87325 Validation Acc: 51.20 ||w1||: 3.74620 ||w2||: 2.79359
# Epochs: 4 Cost: 1.48179 Validation Acc: 69.48 ||w1||: 3.90412 ||w2||: 3.00815
# Epochs: 6 Cost: 1.16322 Validation Acc: 76.62 ||w1||: 4.08775 ||w2||: 3.24805
# Epochs: 8 Cost: 0.94311 Validation Acc: 80.36 ||w1||: 4.26113 ||w2||: 3.46754
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.200000 Batch Size: 100 Alpha: 0.050 Epochs: 50
# [10] Trying parameters - Hidden Nodes: 80 Learning Rate: 0.100000 Batch Size: 25 Alpha: 0.900 Epochs: 40
# Epochs: 0 Cost: 0.70679 Validation Acc: 88.90 ||w1||: 3.47580 ||w2||: 3.43010
# Epochs: 2 Cost: 0.65968 Validation Acc: 88.68 ||w1||: 3.47726 ||w2||: 3.42370
# Epochs: 4 Cost: 0.66759 Validation Acc: 87.48 ||w1||: 3.49301 ||w2||: 3.44242
# Epochs: 6 Cost: 0.67678 Validation Acc: 88.00 ||w1||: 3.47575 ||w2||: 3.43088
# Epochs: 8 Cost: 0.69038 Validation Acc: 80.82 ||w1||: 3.50485 ||w2||: 3.46395
# Epochs: 10 Cost: 0.70546 Validation Acc: 82.46 ||w1||: 3.54375 ||w2||: 3.50752
# Epochs: 12 Cost: 0.72367 Validation Acc: 86.20 ||w1||: 3.56958 ||w2||: 3.53817
# Epochs: 14 Cost: 0.75657 Validation Acc: 71.12 ||w1||: 3.61670 ||w2||: 3.58987
# Epochs: 16 Cost: 0.79074 Validation Acc: 78.10 ||w1||: 3.67317 ||w2||: 3.61854
# Epochs: 18 Cost: 0.82040 Validation Acc: 81.40 ||w1||: 3.70809 ||w2||: 3.64816
# Epochs: 20 Cost: 0.86009 Validation Acc: 81.80 ||w1||: 3.76781 ||w2||: 3.68945
# Epochs: 22 Cost: 0.91274 Validation Acc: 81.48 ||w1||: 3.79208 ||w2||: 3.69294
# Epochs: 24 Cost: 0.96446 Validation Acc: 62.50 ||w1||: 3.91026 ||w2||: 3.80402
# Epochs: 26 Cost: 1.00827 Validation Acc: 67.96 ||w1||: 3.96963 ||w2||: 3.85648
# Epochs: 28 Cost: 1.03699 Validation Acc: 57.96 ||w1||: 4.02493 ||w2||: 3.87759
# Epochs: 30 Cost: 1.11506 Validation Acc: 67.54 ||w1||: 4.15811 ||w2||: 3.98214
# Epochs: 32 Cost: 1.16424 Validation Acc: 83.14 ||w1||: 4.10461 ||w2||: 3.94621
# Epochs: 34 Cost: 1.23869 Validation Acc: 66.94 ||w1||: 4.34728 ||w2||: 4.15268
# Epochs: 36 Cost: 1.29978 Validation Acc: 48.76 ||w1||: 4.33371 ||w2||: 4.07659
# Epochs: 38 Cost: 1.44208 Validation Acc: 59.60 ||w1||: 4.56610 ||w2||: 4.27508
# Current best parameters - Hidden Nodes: 60 Learning Rate: 0.200000 Batch Size: 100 Alpha: 0.050 Epochs: 50
# Best parameters - Hidden Nodes: 60 Learning Rate: 0.200000 Batch Size: 100 Alpha: 0.050 Epochs: 50
# Epochs: 0 Cost: 0.40596 Validation Acc: 93.58 ||w1||: 8.36236 ||w2||: 6.06608
# Epochs: 2 Cost: 0.16528 Validation Acc: 95.94 ||w1||: 9.55663 ||w2||: 7.62233
# Epochs: 4 Cost: 0.12188 Validation Acc: 97.00 ||w1||: 10.18463 ||w2||: 8.44095
# Epochs: 6 Cost: 0.10182 Validation Acc: 97.26 ||w1||: 10.56536 ||w2||: 8.94795
# Epochs: 8 Cost: 0.08951 Validation Acc: 97.34 ||w1||: 10.81485 ||w2||: 9.29945
# Epochs: 10 Cost: 0.08104 Validation Acc: 97.48 ||w1||: 11.01574 ||w2||: 9.58355
# Epochs: 12 Cost: 0.07537 Validation Acc: 97.08 ||w1||: 11.14160 ||w2||: 9.76984
# Epochs: 14 Cost: 0.07094 Validation Acc: 97.40 ||w1||: 11.25996 ||w2||: 9.94351
# Epochs: 16 Cost: 0.06723 Validation Acc: 97.52 ||w1||: 11.35000 ||w2||: 10.07995
# Epochs: 18 Cost: 0.06462 Validation Acc: 97.56 ||w1||: 11.41975 ||w2||: 10.18557
# Epochs: 20 Cost: 0.06257 Validation Acc: 97.62 ||w1||: 11.46688 ||w2||: 10.26303
# Epochs: 22 Cost: 0.06095 Validation Acc: 97.66 ||w1||: 11.51990 ||w2||: 10.34190
# Epochs: 24 Cost: 0.05955 Validation Acc: 97.96 ||w1||: 11.55542 ||w2||: 10.39319
# Epochs: 26 Cost: 0.05854 Validation Acc: 97.70 ||w1||: 11.58768 ||w2||: 10.44227
# Epochs: 28 Cost: 0.05766 Validation Acc: 97.62 ||w1||: 11.61708 ||w2||: 10.47797
# Epochs: 30 Cost: 0.05638 Validation Acc: 97.82 ||w1||: 11.64878 ||w2||: 10.51816
# Epochs: 32 Cost: 0.05599 Validation Acc: 97.86 ||w1||: 11.67672 ||w2||: 10.54904
# Epochs: 34 Cost: 0.05519 Validation Acc: 97.92 ||w1||: 11.70368 ||w2||: 10.57834
# Epochs: 36 Cost: 0.05509 Validation Acc: 97.80 ||w1||: 11.72486 ||w2||: 10.59756
# Epochs: 38 Cost: 0.05470 Validation Acc: 97.08 ||w1||: 11.74996 ||w2||: 10.61599
# Epochs: 40 Cost: 0.05426 Validation Acc: 97.94 ||w1||: 11.76918 ||w2||: 10.62563
# Epochs: 42 Cost: 0.05438 Validation Acc: 97.76 ||w1||: 11.79155 ||w2||: 10.63993
# Epochs: 44 Cost: 0.05351 Validation Acc: 97.80 ||w1||: 11.81233 ||w2||: 10.65384
# Epochs: 46 Cost: 0.05306 Validation Acc: 97.72 ||w1||: 11.83628 ||w2||: 10.67118
# Epochs: 48 Cost: 0.05298 Validation Acc: 97.96 ||w1||: 11.84299 ||w2||: 10.66992
# ('Check grad value is ', 0.11269807856338006)
# Execution time 584 sec
# Training cost: 0.0430374020055
# Validation cost:  0.074184284832
# Testing cost:  0.0757524281601
# Accuracy on Validation set:  97.74 %
# Accuracy on Testing set:  97.88 %

# %%
w_1.shape
# Out:
# (60, 784)

# %%
w_2.shape
# Out:
# (10, 60)

# %%
plt.show(plt.imshow(w_2, cmap='gray'))

# %%
image = np.zeros((28,28))
for i in xrange(0,10):
    temp = w_1[i].reshape(28,28)
    image = np.concatenate((image,temp), axis=1)
img_plt = plt.imshow(image, cmap='gray')
plt.show(img_plt)

# %%
image = np.zeros((28,28))
for i in xrange(10,20):
    temp = w_1[i].reshape(28,28)
    image = np.concatenate((image,temp), axis=1)
img_plt = plt.imshow(image, cmap='gray')
plt.show(img_plt)

# %%
image = np.zeros((28,28))
for i in xrange(20,30):
    temp = w_1[i].reshape(28,28)
    image = np.concatenate((image,temp), axis=1)
img_plt = plt.imshow(image, cmap='gray')
plt.show(img_plt)

# %%
image = w_1[9].reshape(28,28)
img_plt = plt.imshow(image, cmap='gray')
plt.show(img_plt)

# %%
def draw_image(x, y, title_str, drawTest = False):
    for c in range(1, 10):
        plt.subplot(3, 3,c)
        i = np.random.randint(x.shape[0]) 
        predicted, real = predict(x[i], y[i], w1, w2, b1, b2)
        im = testingImages[i].reshape((28,28)) 
        plt.axis("off")
        label = predicted
        plt.title("{} = {}".format(title_str, label))
        plt.imshow(im, cmap='gray')

# %%
draw_image(testingImages, testingLabels, "Label")
